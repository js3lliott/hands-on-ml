# %% [markdown]
# This is a full working notebook going through the code of chapter 2 of Hands on Machine Learning book.
#
# The chapter is a sample of an end-to-end machine learning process, start to finish.

# %%
# Downloading the data from the authors github
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

# defining a function to fetch and download the housing data, create a directory for the file in our workspace,
# and extract the housing.csv file from it in the directory
def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
fetch_housing_data()

# %%
import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
len(housing)
# Out:
# 20640

# %%
housing.shape
# Out:
# (20640, 10)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
housing["ocean_proximity"].values
# Out:
# array(['NEAR BAY', 'NEAR BAY', 'NEAR BAY', ..., 'INLAND', 'INLAND',
#        'INLAND'], dtype=object)

# %%
housing["ocean_proximity"].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

housing.hist(bins=50, figsize=(20, 15))
plt.show();

# %%
import numpy as np
np.random.seed(42)

def split_train_test(data, test_ratio):
    """
    We use the numpy package here to shuffle the data that we pass into the function
    and create a random permutation of it. We then define a variable to create the size
    of the test set we're going to split the data on. From there we define the sizes of the 
    training data and the test set data (based on the size of the test_set_size variable).
    Finally we return the data with fixed indices based upon the sizes created for train and test sets. 
    """
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
train_set, test_set = split_train_test(housing, 0.2)
print(len(train_set))
print(len(test_set))
# Out:
# 16512
# 4128

# %%
# Above, we created our own function to split the data into training and test sets but we can just use the 
# scikit-learn library's train_test_split function
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)

# %% [markdown]
# So far we've used a purely random method for sampling. This is usually fine with a large enough dataset (relative to the number of attributes) but if it's not we run the risk of introducing a significant sampling bias. For proper results we need an accurate representation of the population (dataset), to do this we can introduce what's known as stratified sampling. Scikit-learn has another handy method we can use called StratifiedShuffleSplit.

# %%
fig, ax = plt.subplots(figsize=(12, 12))
housing["income_cat"] = pd.cut(housing["median_income"],
                              bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
                              labels=[1, 2, 3, 4, 5])
housing["income_cat"].hist()
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.iloc[train_index]
    strat_test_set = housing.iloc[test_index]
    
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114583
# 1    0.039729
# Name: income_cat, dtype: float64

# %% [markdown]
# If we were to compare the results of the proportion of income categories represented in a random (normal) shuffling/splitting of the data, the income category data wouldn't be as well represented than in the StratifiedShuffleSplit method (stratified sampling/shuffling).

# %%
# We will remove the income_cat attribute so the data is back to normal. We had done the steps above as an experiment
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)
# Out:
# /Users/jordansamek/opt/miniconda3/envs/hands-on-ml/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
housing = strat_train_set.copy()

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", figsize=(12, 10));

# %%
housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.1, figsize=(12, 10));

# %%
# %config InlineBackend.figure_format = 'retina'

housing.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4,
            s=housing["population"]/100, label="population", figsize=(10, 7),
            c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True);
plt.legend();

# %%
corr_matrix = housing.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.687160
# total_rooms           0.135097
# housing_median_age    0.114110
# households            0.064506
# total_bedrooms        0.047689
# population           -0.026920
# longitude            -0.047432
# latitude             -0.142724
# Name: median_house_value, dtype: float64

# %% [markdown]
# For a correlation matrix, the correlation coefficients range from -1 to 1. When the value of a variable is close to 1, it means that there is a strong positive correlation. For example, when the median_house_value goes up the nedian_income tends to go up as well. When the value of a varible is close to -1 that means there is a negative correlation. As we can see there is a small negative correlation between latitude and median_house_value. When the value is 0 that means there is no correlation at all between variables.

# %% [markdown]
# Another way to check for correlation between attributes is to use Pandas' scatter_matrix function, which plots every numerical attribute against every other numerical attribute. We will use that next to see if there are any other relations we haven't seen yet or if there are any confirmations about our data.

# %%
from pandas.plotting import scatter_matrix

attributes = ["median_house_value", "median_income", "total_rooms", "housing_median_age"]
scatter_matrix(housing[attributes], figsize=(15, 15));

# %% [markdown]
# The most promising attribute to predict the median_house_value seems to be median_income, so let's zoom in on this feature.

# %%
housing.plot(kind="scatter", x="median_income", y="median_house_value", alpha=0.1);

# %% [markdown]
# We can see that there are a few quirks with these two features plotted against each other. There are a few plateaus at different median house values. These can possibly affect our algorithms because they could be reproduced by the models. We may want to consider removing these quirks before implementing an algorithm.

# %% [markdown]
# Next, we will try and experiment with different attribute combinations. For example, we have a total_rooms variable that unfortunately doesn't help with how many rooms per house, bedrooms per house, etc., affects our house price. we will create a few new variables so they can be accurately represented in our dataset to help predict the house price in the end.

# %%
housing["rooms_per_household"] = housing["total_rooms"] / housing["households"]
housing["bedrooms_per_household"] = housing["total_bedrooms"] / housing["total_rooms"]
housing["population_per_household"] = housing["population"] / housing["households"]

# %%
corr_matrix = housing.corr()
corr_matrix["median_house_value"].sort_values(ascending=False)
# Out:
# median_house_value          1.000000
# median_income               0.687160
# rooms_per_household         0.146285
# total_rooms                 0.135097
# housing_median_age          0.114110
# households                  0.064506
# total_bedrooms              0.047689
# population_per_household   -0.021985
# population                 -0.026920
# longitude                  -0.047432
# latitude                   -0.142724
# bedrooms_per_household     -0.259984
# Name: median_house_value, dtype: float64

# %% [markdown]
# We can get a better picture of how the new combination of attributes positively or negatively correlates with median_house_value. The new bedrooms_per_household attribute is much more correlated with median_house_value than the total number of rooms or bedrooms. According to the correlation matrix, a lower bedroom to room ratio tends to make the house more expensive. As well as the total number of rooms per household tends to make the house price more expensive which makes sense since the larger the house/room number the more it would be.

# %% [markdown]
# This round of exploration doesn't need to be too thorough. The point is to start off on the right foot and quickly gain insghts that will help us get a first reasonably good prototype. We will move on to preparing the data for some machine learning algorithms.
#
# Instead of doing this manually, we should write functions to do this. It will allow us to reproduce transformations easily on any dataset. We can gradually build a library of transformation functions to reuse in future projects. We can use these following functions in a live system to transform new data before feeding it into our algorithms and it will make it possible for us to easily try various transformations and see which combination of transformations work best.
#
# We'll start with a clean dataset and separate the predictors and labels because we don't want to apply the same transformations to them.

# %%
housing = strat_train_set.drop("median_house_value", axis=1)
housing_labels = strat_train_set["median_house_value"].copy()

# %%
housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        158
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="median")
housing_num = housing.drop("ocean_proximity", axis=1)
imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([-118.51  ,   34.26  ,   29.    , 2119.5   ,  433.    , 1164.    ,
#         408.    ,    3.5409])

# %%
housing_num.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        158
# population              0
# households              0
# median_income           0
# dtype: int64

# %%
housing_num.median().values
# Out:
# array([-118.51  ,   34.26  ,   29.    , 2119.5   ,  433.    , 1164.    ,
#         408.    ,    3.5409])

# %% [markdown]
# Now we can use this trained imputer to transform the training set by replacing missing values by the learned medians.

# %%
X = imputer.transform(housing_num)

# %% [markdown]
# The result is a plain numpy array containing the transformed features. We can put this back into a pandas DataFrame if we want by doing the following.

# %%
housing_tr = pd.DataFrame(X, columns=housing_num.columns)

# %% [markdown]
# We're now going to handle text and categorical attributes from the dataset.

# %%
housing_cat = housing[["ocean_proximity"]]
housing_cat.head(10)
# Out:
#       ocean_proximity
# 17606       <1H OCEAN
# 18632       <1H OCEAN
# 14650      NEAR OCEAN
# 3230           INLAND
# 3555        <1H OCEAN
# 19480          INLAND
# 8879        <1H OCEAN
# 13685          INLAND
# 4937        <1H OCEAN
# 4861        <1H OCEAN

# %%
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

housing_cat_encoded = ordinal_encoder.fit_transform(housing_cat)
housing_cat_encoded[:10]
# Out:
# array([[0.],
#        [0.],
#        [4.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [0.]])

# %%
ordinal_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# We've converted the categorical attribute "ocean_proximity" to ordinal values 0 through 4. One issue that arises with this technique is that the algorithm will assume that two nearby values (0 and 1 for example) are more similar than two distant values (0 and 4). This is fine for some cases but as we can see here, 0 and 4 are more similar than the values that represent the attributes at 0 and 1. To fix this issue we might deicde to create one binary attribute per category: one attribute equal to 1 when the category is present and all others equal 0. This is known as one-hot encoding. 1 represents and attribute that is present (hot), and 0 represents that the attribute is cold and not present at that instance.

# %%
from sklearn.preprocessing import OneHotEncoder
cat_encoder = OneHotEncoder()
housing_cat_1hot = cat_encoder.fit_transform(housing_cat)
housing_cat_1hot
# Out:
# <16512x5 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16512 stored elements in Compressed Sparse Row format>

# %%
cat_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# Alot of times we will have to create our own tasks/custom cleanup operations and ways to combine specific attributes.
# Scikit-learn provides many useful transformers but what we want to do is create different pipelines to work seamlessly with the Scikit-learn API, and functionalities. Below we will implement some custom functions that will help us with transformations.

# %%
housing.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17606    -121.89     37.29                38.0       1568.0           351.0
# 18632    -121.93     37.05                14.0        679.0           108.0
# 14650    -117.20     32.77                31.0       1952.0           471.0
# 3230     -119.61     36.31                25.0       1847.0           371.0
# 3555     -118.59     34.23                17.0       6592.0          1525.0
#
#        population  households  median_income ocean_proximity
# 17606       710.0       339.0         2.7042       <1H OCEAN
# 18632       306.0       113.0         6.4214       <1H OCEAN
# 14650       936.0       462.0         2.8621      NEAR OCEAN
# 3230       1460.0       353.0         1.8839          INLAND
# 3555       4459.0      1463.0         3.0347       <1H OCEAN

# %%
from sklearn.base import BaseEstimator, TransformerMixin

rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room=True):   # no *args or **kwargs
        self.add_bedrooms_per_room = add_bedrooms_per_room
    
    def fit(self, X, y=None):
        return self  # nothing else to do
    
    def transform(self, X, y=None):
        rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
        population_per_household = X[:, population_ix] / X[:, households_ix]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]
        
attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)
housing_extra_attribs = attr_adder.transform(housing.values)

# %% [markdown]
# Feature scaling is the next step in the process before feeding our data to a machine learning algorithm. ML algorithms don't perform well when the input numerical attributes have very different scales. For this particular dataset we have total number of rooms ranging from 6 to 39,320 while median incomes range from 0 to 15.
#
# There are two common ways to get all attributes to have the same scale: min-max scaling and standardization.
#
# Min-max scaling (also known as normalization) is quite simple: values are shifted and rescaled so that they end up ranging from 0 to 1. We do this by subtracting the min value and dividing by the max minus the min. Sckit-learn provides a transformer called MinMaxScaler for this. It has a feature range hyperparameter that lets us change the range if we don't want 0-1.
#
# Standardization is a but different: first it subtracts the mean value (so standardized values always have a zero mean), and then it divides by the standard deviation so that the resulting distributiong has unit variance. Standardization does not bound values to a specific range, which may be a problem for some algorithms, but it's much less affected by outliers. For this type of feature scaling we can use the StandardScaler() class from Scikit-learn.
#
# With all the transformations, it's important to fit the scalers to the training data, not the full dataset.

# %%
# small pipeline for the numerical attributes
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy="median")),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler()),
])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %% [markdown]
# So far we've handled the categorical columns and numerical columns separately. It would be more convenient to have a single transformer able to handle all columns, applying the appropriate transformations to each column. Scikit-learn has ColumnTransformer for this purpose. We'll use it to apply all the transformations to the housing data.

# %%
from sklearn.compose import ColumnTransformer

num_attribs = list(housing_num)
cat_attribs = ["ocean_proximity"]

full_pipeline = ColumnTransformer([
    ("num", num_pipeline, num_attribs),
    ("cat", OneHotEncoder(), cat_attribs),
])

housing_prepared = full_pipeline.fit_transform(housing)

# %% [markdown]
# Here's how the above works: first we import the ColumnTransformer class, next we get the list of numerical column names and the list of categorical column names, and we construct a ColumnTransformer. The constructor requires a list of tuples, wehre each tuple contains a name, a transformer, and a ;ist of names (or indices) of columns that the transformer should be applied to.
#
# In this example we specify that the numerical columns should be transformed using the num_pipeline we defined earlier, and the categorical columns should be transformed using the OneHotEncoder. Finally, we apply the ColumnTransformer to the housing data. It applies each transformer to the appropriate columns and concatenates the outputs along the second axis.

# %% [markdown]
# Now we can finally get to selecting and training some ML models. We'll start with a Linear Regression model.

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()

# %%
lin_reg.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression()

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels.iloc[:5]
some_data_prepared = full_pipeline.transform(some_data)
print("Predictions:", lin_reg.predict(some_data_prepared))
print("Labels:", list(some_labels))
# Out:
# Predictions: [210644.60459286 317768.80697211 210956.43331178  59218.98886849
#  189747.55849879]
# Labels: [286600.0, 340600.0, 196900.0, 46300.0, 254500.0]

# %%
# calculate the error of prediction vs actual values by using mean_squared_error
from sklearn.metrics import mean_squared_error

housing_predictions = lin_reg.predict(housing_prepared)
lin_mse = mean_squared_error(housing_labels, housing_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 68628.19819848922

# %% [markdown]
# This means that we have a typical prediction error of $68,628, which is not very good at all. This is an example of model underfitting the training data. When this happens it means that the features do not provide enough information to make good predictions, or that the model isn't powerful enough. Ways to combat underfitting are to select a more powerful model, feed better features into the model or to reduce the constraints on the model. This model is not regularized which means we can rule out the last option. Let's try and select a more powerful model, in this case we'll select DecisionTreeRegresor

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(housing_prepared, housing_labels)
# Out:
# DecisionTreeRegressor()

# %%
housing_predictions = tree_reg.predict(housing_prepared)
tree_mse = mean_squared_error(housing_labels, housing_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# In this case we've gotten zero errors at all which means that we've badly overfit the data since we can't possibly have acheived a perfect score. We'll validate this by using cross-validation. Specifically we'll use the scikit-learn k-fold cross validation feature. The following code randomly splits the training data into 10 distinct subsets called folds, then it trains and evaluates the Decision Tree model 10 times, picking a different fold for evaluation every time and trainging on the other 9 folds. This results in an array containing the 10 evaluation scores.

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, housing_prepared, housing_labels,
                        scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())
    
display_scores(tree_rmse_scores)
# Out:
# Scores: [69327.01708558 65486.39211857 71358.25563341 69091.37509104
#  70570.20267046 75529.94622521 69895.20650652 70660.14247357
#  75843.74719231 68905.17669382]
# Mean: 70666.74616904806
# Standard deviation: 2928.322738055112

# %% [markdown]
# We can see that the Decision Tree model now looks worse than the previous Linear Regression model that we used. Let's compute the cross val scores for the Linear Regression model to compare results.

# %%
lin_scores = cross_val_score(lin_reg, housing_prepared, housing_labels,
                             scoring="neg_mean_squared_error", cv=10)

lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [66782.73843989 66960.118071   70347.95244419 74739.57052552
#  68031.13388938 71193.84183426 64969.63056405 68281.61137997
#  71552.91566558 67665.10082067]
# Mean: 69052.46136345083
# Standard deviation: 2731.674001798348

# %% [markdown]
# We'll try one more model: RandomForestRegressor(). Random Forests work by training many Decision Trees on random subsets of the features, then averaging out their predictions. Building a model on top of many other models is called Ensemble Learning, and it is often a great way to push ML algorithms even further.

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor()
forest_reg.fit(housing_prepared, housing_labels)
# Out:
# RandomForestRegressor()

# %%
housing_predictions = forest_reg.predict(housing_prepared)
forest_mse = mean_squared_error(housing_labels, housing_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 18680.294240259147

# %%
forest_scores = cross_val_score(forest_reg, housing_prepared, housing_labels,
                               scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [49557.6095063  47584.54435547 49605.349788   52325.13724488
#  49586.9889247  53154.87424699 48800.48987508 47880.32844243
#  52958.68645964 50046.17489414]
# Mean: 50150.018373763225
# Standard deviation: 1902.0697041387534

# %% [markdown]
# #### Chapter 2 - Exercises: Question 1

# %%
from sklearn.svm import SVR

sv_reg = SVR(kernel='linear', C=10)
sv_reg.fit(housing_prepared, housing_labels)
# Out:
# SVR(C=10, kernel='linear')

# %%
housing_predictions = sv_reg.predict(housing_prepared)
sv_mse = mean_squared_error(housing_labels, housing_predictions)
sv_rmse = np.sqrt(sv_mse)
sv_rmse
# Out:
# 81933.17308297305

# %%
svr_scores = cross_val_score(sv_reg, housing_prepared, housing_labels,
                            scoring="neg_mean_squared_error", cv=10)
svr_rmse_scores = np.sqrt(-svr_scores)
display_scores(svr_rmse_scores)
# Out:
# Scores: [79791.21028234 82279.28716396 81358.04206403 83926.52589404
#  81734.77042678 87042.16585301 80328.62514731 84133.2461885
#  86310.93974092 83748.06798686]
# Mean: 83065.288074775
# Standard deviation: 2284.9494103238626

# %%
sv2_reg = SVR(kernel='rbf', C=10)
sv2_reg.fit(housing_prepared, housing_labels)
# Out:
# SVR(C=10)

# %%
housing_predictions = sv2_reg.predict(housing_prepared)
sv2_mse = mean_squared_error(housing_labels, housing_predictions)
sv2_rmse = np.sqrt(sv2_mse)
sv2_rmse
# Out:
# 115457.1215403194

# %%
svr2_scores = cross_val_score(sv2_reg, housing_prepared, housing_labels,
                            scoring="neg_mean_squared_error", cv=10)
svr2_rmse_scores = np.sqrt(-svr2_scores)
display_scores(svr2_rmse_scores)
# Out:
# Scores: [108757.03523302 116594.19757311 114175.42845194 117564.63753421
#  114726.94736733 119583.91936678 114704.97815868 118654.20151435
#  117530.31247849 115207.23387715]
# Mean: 115749.88915550434
# Standard deviation: 2900.3887612267436

# %%
for c in range(11, 100):
    svr_reg = SVR(kernel='linear', C=c)
    svr_reg.fit(housing_prepared, housing_labels)
    housing_predictions = svr_reg.predict(housing_prepared)
    svr_reg_mse = mean_squared_error(housing_labels, housing_predictions)
    svr_reg_rmse = np.sqrt(svr_reg_mse).mean()
    
    
    print("Support Vector Machine accuracy for C={}: {:.2f}".format(c, svr_reg_rmse))
# Out:
# Support Vector Machine accuracy for C=11: 81276.00
# Support Vector Machine accuracy for C=12: 80536.19
# Support Vector Machine accuracy for C=13: 79816.05
# Support Vector Machine accuracy for C=14: 79238.09
# Support Vector Machine accuracy for C=15: 78574.72
# Support Vector Machine accuracy for C=16: 78054.07
# Support Vector Machine accuracy for C=17: 77562.91
# Support Vector Machine accuracy for C=18: 77159.35
# Support Vector Machine accuracy for C=19: 76748.81
# Support Vector Machine accuracy for C=20: 76331.85
# Support Vector Machine accuracy for C=21: 76100.97
# Support Vector Machine accuracy for C=22: 75883.03
# Support Vector Machine accuracy for C=23: 75630.45
# Support Vector Machine accuracy for C=24: 75420.59
# Support Vector Machine accuracy for C=25: 75190.39
# Support Vector Machine accuracy for C=26: 75002.40
# Support Vector Machine accuracy for C=27: 74822.11
# Support Vector Machine accuracy for C=28: 74654.82
# ...

# %% [markdown]
# ### Fine tuning the model
#
# We now have a shortlist of promising models, and we need to fine tune them. One way to go about this task is to use a method called Grid Search.
#
# Fine tuning a model requires fiddling with the hyperparameters, which over all of the models would be a very tedious task. What we could use is Scikit-learn's GridSearchCV to do this work for us. All we need to do is tell it which hyperparameters we want to experiment with and what values to try out, and it will evaluate all possible combinations of hyperparameter values using cross-validation. Let's do this for the RandomForestRegressor model.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
]

forest_reg = RandomForestRegressor()
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                          scoring="neg_mean_squared_error",
                          return_train_score=True)
grid_search.fit(housing_prepared, housing_labels)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_params_
# Out:
# {'max_features': 6, 'n_estimators': 30}

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=6, n_estimators=30)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 64300.09435877069 {'max_features': 2, 'n_estimators': 3}
# 55384.57502251906 {'max_features': 2, 'n_estimators': 10}
# 53058.21730325412 {'max_features': 2, 'n_estimators': 30}
# 60454.41540924483 {'max_features': 4, 'n_estimators': 3}
# 52504.48273914367 {'max_features': 4, 'n_estimators': 10}
# 50884.82031744209 {'max_features': 4, 'n_estimators': 30}
# 60072.11434172147 {'max_features': 6, 'n_estimators': 3}
# 52042.47008955875 {'max_features': 6, 'n_estimators': 10}
# 50002.31952534388 {'max_features': 6, 'n_estimators': 30}
# 58224.281300424555 {'max_features': 8, 'n_estimators': 3}
# 51990.13744470298 {'max_features': 8, 'n_estimators': 10}
# 50072.278630697045 {'max_features': 8, 'n_estimators': 30}
# 62164.760014591724 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 54645.06766683037 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 60419.54939918208 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %% [markdown]
# Grid search is a good approach when there are relatively few combinations, but when the hyperparameter search space is large it might be best to use RandomizedSearchCV. Instead of trying out all possible combinations, it evaluates a given number of random combinations by selecting a random value for each hyperparameter at every iteration.

# %%
from sklearn.model_selection import RandomizedSearchCV
import scipy
from scipy.stats import randint

param_dist = {
    'n_estimators': randint(low=1, high=200),
    'max_features': randint(low=1, high=8),
}
forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_dist,
                               n_iter=10, cv=5, scoring="neg_mean_squared_error", random_state=42)
rnd_search.fit(housing_prepared, housing_labels)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=42),
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fdfaafb48e0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7fdfaaf3d790>},
#                    random_state=42, scoring='neg_mean_squared_error')

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 49150.70756927707 {'max_features': 7, 'n_estimators': 180}
# 51389.889203389284 {'max_features': 5, 'n_estimators': 15}
# 50796.155224308866 {'max_features': 3, 'n_estimators': 72}
# 50835.13360315349 {'max_features': 5, 'n_estimators': 21}
# 49280.9449827171 {'max_features': 7, 'n_estimators': 122}
# 50774.90662363929 {'max_features': 3, 'n_estimators': 75}
# 50682.78888164288 {'max_features': 3, 'n_estimators': 88}
# 49608.99608105296 {'max_features': 5, 'n_estimators': 100}
# 50473.61930350219 {'max_features': 3, 'n_estimators': 150}
# 64429.84143294435 {'max_features': 5, 'n_estimators': 2}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([7.39643917e-02, 6.90573553e-02, 4.12777730e-02, 1.80424443e-02,
#        1.67582630e-02, 1.73496782e-02, 1.57353982e-02, 3.06039658e-01,
#        5.76403732e-02, 1.11529594e-01, 7.63335647e-02, 1.09898907e-02,
#        1.79166100e-01, 1.01729611e-04, 2.92245229e-03, 3.09133428e-03])

# %%
extra_attribs = ["rooms_per_hhold", "pop_per_hhold", "bedrooms_per_room"]
cat_encoder = full_pipeline.named_transformers_["cat"]
cat_one_hot_attribs = list(cat_encoder.categories_[0])
attributes = num_attribs + extra_attribs + cat_one_hot_attribs
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.30603965814850226, 'median_income'),
#  (0.17916609960626215, 'INLAND'),
#  (0.11152959367164038, 'pop_per_hhold'),
#  (0.07633356472213657, 'bedrooms_per_room'),
#  (0.0739643917221035, 'longitude'),
#  (0.06905735526183748, 'latitude'),
#  (0.057640373178562264, 'rooms_per_hhold'),
#  (0.04127777296608005, 'housing_median_age'),
#  (0.0180424443381609, 'total_rooms'),
#  (0.017349678176456253, 'population'),
#  (0.01675826304369493, 'total_bedrooms'),
#  (0.01573539823613609, 'households'),
#  (0.01098989074597071, '<1H OCEAN'),
#  (0.003091334281993749, 'NEAR OCEAN'),
#  (0.0029224522894530686, 'NEAR BAY'),
#  (0.00010172961100968198, 'ISLAND')]

# %%
final_model = grid_search.best_estimator_

X_test = strat_test_set.drop("median_house_value", axis=1)
y_test = strat_test_set["median_house_value"].copy()

X_test_prepared = full_pipeline.transform(X_test)

final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)
final_rmse
# Out:
# 47844.64045810312

# %% [markdown]
# Sometimes such a point estimate of the generalization error will not be enough to convince confidence in the model. To get an idea of how precise the estimate is, we can compute the 95% confidence-interval for the generalization error using scipy.stats.t.interval():

# %%
from scipy import stats

confidence = 0.95
squared_errors = (final_predictions - y_test)**2
np.sqrt(stats.t.interval(confidence, len(squared_errors)-1,
                        loc=squared_errors.mean(),
                        scale=stats.sem(squared_errors)))
# Out:
# array([45881.44338516, 49730.39708292])

# %% [markdown]
# ### Exercise Solutions:
# #### Question 1
# Question: Try a Support Vector Machine regressor (sklearn.svm.SVR), with various hyperparameters such as kernel="linear" (with various values for the C hyperparameter) or kernel="rbf" (with various values for the C and gamma hyperparameters). Don't worry about what these hyperparameters mean for now. How does the best SVR predictor perform?

# %%
from sklearn.model_selection import GridSearchCV

params_grid = [
    {'kernel': ['linear'], 'C': [10., 30., 100., 300., 1000., 3000., 10000., 30000.0]},
    {'kernel': ['rbf'], 'C': [1.0, 3.0, 10., 30., 100., 300., 1000.0], 
     'gamma': [0.01, 0.03, 0.1, 0.3, 1.0, 3.0]},
]

svm_reg = SVR()
grid_search = GridSearchCV(svm_reg, params_grid, cv=5, scoring="neg_mean_squared_error", verbose=2)
grid_search.fit(housing_prepared, housing_labels)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] C=10.0, kernel=linear ...........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ............................ C=10.0, kernel=linear, total=   4.5s
# [CV] C=10.0, kernel=linear ...........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.5s remaining:    0.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-2bb7c641455a> in <module>
#       9 svm_reg = SVR()
#      10 grid_search = GridSearchCV(svm_reg, params_grid, cv=5, scoring="neg_mean_squared_error", verbose=2)
# ---> 11 grid_search.fit(housing_prepared, housing_labels)
#
# ~/opt/miniconda3/envs/hands-on-ml/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
# ...

# %%
negative_mse = grid_search.best_score_
rmse = np.sqrt(-negative_mse)
rmse

# %%
grid_search.best_params_

# %% [markdown]
# We can see that the RMSE is much worse than the RandomForestRegressor. After checking the hyperparameters we can see that a 'linear' kernel was the optimal kernel to use, but for our C value we can see that the best parameter is the max value we have chosen. We may want to test for much higher values of C to see how the RMSE changes.

# %% [markdown]
# #### Question 2
# Try replacing GridSearchCV with RandomizedSearchCV.

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import expon, reciprocal


# Note: gamma is ignored when kernel is "linear"
param_distribs = {
        'kernel': ['linear', 'rbf'],
        'C': reciprocal(20, 200000),
        'gamma': expon(scale=1.0),
    }

svm_reg = SVR()
rnd_search = RandomizedSearchCV(svm_reg, param_distributions=param_distribs,
                                n_iter=50, cv=5, scoring='neg_mean_squared_error',
                                verbose=2, random_state=42)
rnd_search.fit(housing_prepared, housing_labels)

# %%
negative_mse = rnd_search.best_score_
rmse = np.sqrt(-negative_mse)
rmse

# %%
rnd_search.best_params_

# %%
expon_distrib = expon(scale=1.)
samples = expon_distrib.rvs(10000, random_state=42)
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.title("Exponential distribution (scale=1.0)")
plt.hist(samples, bins=50)
plt.subplot(122)
plt.title("Log of this distribution")
plt.hist(np.log(samples), bins=50)
plt.show();

# %%
reciprocal_distrib = reciprocal(20, 200000)
samples = reciprocal_distrib.rvs(10000, random_state=42)
plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.title("Reciprocal distribution (scale=1.0)")
plt.hist(samples, bins=50)
plt.subplot(122)
plt.title("Log of this distribution")
plt.hist(np.log(samples), bins=50)
plt.show();

# %% [markdown]
# #### Question 3
# Try adding a transformer in the preparation pipeline to select only the most important attributes

# %%
from sklearn.base import TransformerMixin, BaseEstimator

def indices_of_top_k(arr, k):
    return np.sort(np.argpartition(np.array(arr), -k)[-k:])

class TopFeaturesSelector(BaseEstimator, TransformerMixin):
    def __init__(self, feature_importances, k):
        self.feature_importances = feature_importances
        self.k = k
        
    def fit(self, X, y=None):
        self.feature_indices_ = indices_of_top_k(self.feature_importances, self.k)
        return self
    
    def transform(self, X):
        return X[:, self.feature_indices_]
